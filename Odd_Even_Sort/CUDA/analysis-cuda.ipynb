# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
print("done")
# Out:
# done

# %%
tk = th.Thicket.from_caliperreader(glob("Semester-Project/Online-Implementation/CUDA/**/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("Semester-Project/Jace-Test/CUDA-Cali/**/*.cali"))
# tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Variance time/rank", "Total time"], axis = 1)
tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank",
                                  "Avg time/rank", "Min GPU Time/rank", "Max GPU Time/rank", "Total GPU Time"], axis = 1)
# tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank",
#                                   "Avg GPU Time/rank", "Min GPU Time/rank", "Max GPU Time/rank", "Total GPU Time"], axis = 1)
# tk.dataframe = tk.dataframe.drop(["nid", "spot.channel", "Total time", "Min time/rank", "Max time/rank"], axis = 1)
print("done")
# Out:
# done

# %%
tk.dataframe
# Out:
#                                                               Avg GPU Time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              93128221             1.765123
#                                                   461731006            1.803983
#                                                   1031478014           7.330431
#                                                   1280442648           0.556269
#                                                   1319540244           7.037757
#                                                   1328559098         126.220451
#                                                   1332111728           7.142552
#                                                   1452960576          63.520380
#                                                   1478370368         151.465133
#                                                   1946229938           0.550315
#                                                   2148516230           0.576361
#                                                   2514692867         126.528247
#                                                   2817310001          91.380895
#                                                   2929251895         341.979468
#                                                   2939990776          51.852726
#                                                   2969711491           1.732489
#                                                   3491640172         124.918204
#                                                   3720363797          31.222585
#                                                   3902313032          31.220316
#                                                   3965961082          31.523202
# {'name': 'comm', 'type': 'function'}              93128221             0.003429
#                                                   461731006            0.003411
#                                                   1031478014           0.003417
#                                                   1280442648           0.003414
#                                                   1319540244           0.003391
#                                                   1328559098           0.004187
#                                                   1332111728           0.003422
#                                                   1452960576           0.003398
#                                                   1478370368           0.003449
#                                                   1946229938           0.003411
#                                                   2148516230           0.003421
#                                                   2514692867           0.003412
#                                                   2817310001           0.003396
#                                                   2929251895           0.003439
#                                                   2939990776           0.003426
#                                                   2969711491           0.003419
#                                                   3491640172           0.003425
#                                                   3720363797           0.003406
#                                                   3902313032           0.004073
#                                                   3965961082           0.003413
# {'name': 'comm_large', 'type': 'function'}        93128221             0.003429
#                                                   461731006            0.003411
#                                                   1031478014           0.003417
#                                                   1280442648           0.003414
#                                                   1319540244           0.003391
#                                                   1328559098           0.004187
#                                                   1332111728           0.003422
#                                                   1452960576           0.003398
#                                                   1478370368           0.003449
#                                                   1946229938           0.003411
#                                                   2148516230           0.003421
#                                                   2514692867           0.003412
#                                                   2817310001           0.003396
#                                                   2929251895           0.003439
#                                                   2939990776           0.003426
#                                                   2969711491           0.003419
#                                                   3491640172           0.003425
#                                                   3720363797           0.003406
#                                                   3902313032           0.004073
#                                                   3965961082           0.003413
# {'name': 'comp', 'type': 'function'}              93128221             1.758157
#                                                   461731006            1.797003
#                                                   1031478014           7.323131
#                                                   1280442648           0.549585
#                                                   1319540244           7.030888
#                                                   1328559098         126.212564
#                                                   1332111728           7.135292
#                                                   1452960576          63.513618
#                                                   1478370368         151.458182
#                                                   1946229938           0.543637
#                                                   2148516230           0.569523
#                                                   2514692867         126.521378
#                                                   2817310001          91.373804
#                                                   2929251895         341.972144
#                                                   2939990776          51.845931
#                                                   2969711491           1.725632
#                                                   3491640172         124.911262
#                                                   3720363797          31.215352
#                                                   3902313032          31.212755
#                                                   3965961082          31.516228
# {'name': 'comp_large', 'type': 'function'}        93128221             1.758157
#                                                   461731006            1.797003
#                                                   1031478014           7.323131
#                                                   1280442648           0.549585
#                                                   1319540244           7.030888
#                                                   1328559098         126.212564
#                                                   1332111728           7.135292
#                                                   1452960576          63.513618
#                                                   1478370368         151.458182
#                                                   1946229938           0.543637
#                                                   2148516230           0.569523
#                                                   2514692867         126.521378
#                                                   2817310001          91.373804
#                                                   2929251895         341.972144
#                                                   2939990776          51.845931
#                                                   2969711491           1.725632
#                                                   3491640172         124.911262
#                                                   3720363797          31.215352
#                                                   3902313032          31.212755
#                                                   3965961082          31.516228
# {'name': 'comp_small', 'type': 'function'}        93128221                  NaN
#                                                   461731006                 NaN
#                                                   1031478014                NaN
#                                                   1280442648                NaN
#                                                   1319540244                NaN
#                                                   1328559098                NaN
#                                                   1332111728                NaN
#                                                   1452960576                NaN
#                                                   1478370368                NaN
#                                                   1946229938                NaN
#                                                   2148516230                NaN
#                                                   2514692867                NaN
#                                                   2817310001                NaN
#                                                   2929251895                NaN
#                                                   2939990776                NaN
#                                                   2969711491                NaN
#                                                   3491640172                NaN
#                                                   3720363797                NaN
#                                                   3902313032                NaN
#                                                   3965961082                NaN
# {'name': 'correctness_check', 'type': 'function'} 93128221                  NaN
#                                                   461731006                 NaN
#                                                   1031478014                NaN
#                                                   1280442648                NaN
#                                                   1319540244                NaN
#                                                   1328559098                NaN
#                                                   1332111728                NaN
#                                                   1452960576                NaN
#                                                   1478370368                NaN
#                                                   1946229938                NaN
#                                                   2148516230                NaN
#                                                   2514692867                NaN
#                                                   2817310001                NaN
#                                                   2929251895                NaN
#                                                   2939990776                NaN
#                                                   2969711491                NaN
#                                                   3491640172                NaN
#                                                   3720363797                NaN
#                                                   3902313032                NaN
#                                                   3965961082                NaN
# {'name': 'data_init', 'type': 'function'}         93128221                  NaN
#                                                   461731006                 NaN
#                                                   1031478014                NaN
#                                                   1280442648                NaN
#                                                   1319540244                NaN
#                                                   1328559098                NaN
#                                                   1332111728                NaN
#                                                   1452960576                NaN
#                                                   1478370368                NaN
#                                                   1946229938                NaN
#                                                   2148516230                NaN
#                                                   2514692867                NaN
#                                                   2817310001                NaN
#                                                   2929251895                NaN
#                                                   2939990776                NaN
#                                                   2969711491                NaN
#                                                   3491640172                NaN
#                                                   3720363797                NaN
#                                                   3902313032                NaN
#                                                   3965961082                NaN
#
#                                                                            name
# node                                              profile
# {'name': 'main', 'type': 'function'}              93128221                 main
#                                                   461731006                main
#                                                   1031478014               main
#                                                   1280442648               main
#                                                   1319540244               main
#                                                   1328559098               main
#                                                   1332111728               main
#                                                   1452960576               main
#                                                   1478370368               main
#                                                   1946229938               main
#                                                   2148516230               main
#                                                   2514692867               main
#                                                   2817310001               main
#                                                   2929251895               main
#                                                   2939990776               main
#                                                   2969711491               main
#                                                   3491640172               main
#                                                   3720363797               main
#                                                   3902313032               main
#                                                   3965961082               main
# {'name': 'comm', 'type': 'function'}              93128221                 comm
#                                                   461731006                comm
#                                                   1031478014               comm
#                                                   1280442648               comm
#                                                   1319540244               comm
#                                                   1328559098               comm
#                                                   1332111728               comm
#                                                   1452960576               comm
#                                                   1478370368               comm
#                                                   1946229938               comm
#                                                   2148516230               comm
#                                                   2514692867               comm
#                                                   2817310001               comm
#                                                   2929251895               comm
#                                                   2939990776               comm
#                                                   2969711491               comm
#                                                   3491640172               comm
#                                                   3720363797               comm
#                                                   3902313032               comm
#                                                   3965961082               comm
# {'name': 'comm_large', 'type': 'function'}        93128221           comm_large
#                                                   461731006          comm_large
#                                                   1031478014         comm_large
#                                                   1280442648         comm_large
#                                                   1319540244         comm_large
#                                                   1328559098         comm_large
#                                                   1332111728         comm_large
#                                                   1452960576         comm_large
#                                                   1478370368         comm_large
#                                                   1946229938         comm_large
#                                                   2148516230         comm_large
#                                                   2514692867         comm_large
#                                                   2817310001         comm_large
#                                                   2929251895         comm_large
#                                                   2939990776         comm_large
#                                                   2969711491         comm_large
#                                                   3491640172         comm_large
#                                                   3720363797         comm_large
#                                                   3902313032         comm_large
#                                                   3965961082         comm_large
# {'name': 'comp', 'type': 'function'}              93128221                 comp
#                                                   461731006                comp
#                                                   1031478014               comp
#                                                   1280442648               comp
#                                                   1319540244               comp
#                                                   1328559098               comp
#                                                   1332111728               comp
#                                                   1452960576               comp
#                                                   1478370368               comp
#                                                   1946229938               comp
#                                                   2148516230               comp
#                                                   2514692867               comp
#                                                   2817310001               comp
#                                                   2929251895               comp
#                                                   2939990776               comp
#                                                   2969711491               comp
#                                                   3491640172               comp
#                                                   3720363797               comp
#                                                   3902313032               comp
#                                                   3965961082               comp
# {'name': 'comp_large', 'type': 'function'}        93128221           comp_large
#                                                   461731006          comp_large
#                                                   1031478014         comp_large
#                                                   1280442648         comp_large
#                                                   1319540244         comp_large
#                                                   1328559098         comp_large
#                                                   1332111728         comp_large
#                                                   1452960576         comp_large
#                                                   1478370368         comp_large
#                                                   1946229938         comp_large
#                                                   2148516230         comp_large
#                                                   2514692867         comp_large
#                                                   2817310001         comp_large
#                                                   2929251895         comp_large
#                                                   2939990776         comp_large
#                                                   2969711491         comp_large
#                                                   3491640172         comp_large
#                                                   3720363797         comp_large
#                                                   3902313032         comp_large
#                                                   3965961082         comp_large
# {'name': 'comp_small', 'type': 'function'}        93128221           comp_small
#                                                   461731006          comp_small
#                                                   1031478014         comp_small
#                                                   1280442648         comp_small
#                                                   1319540244         comp_small
#                                                   1328559098         comp_small
#                                                   1332111728         comp_small
#                                                   1452960576         comp_small
#                                                   1478370368         comp_small
#                                                   1946229938         comp_small
#                                                   2148516230         comp_small
#                                                   2514692867         comp_small
#                                                   2817310001         comp_small
#                                                   2929251895         comp_small
#                                                   2939990776         comp_small
#                                                   2969711491         comp_small
#                                                   3491640172         comp_small
#                                                   3720363797         comp_small
#                                                   3902313032         comp_small
#                                                   3965961082         comp_small
# {'name': 'correctness_check', 'type': 'function'} 93128221    correctness_check
#                                                   461731006   correctness_check
#                                                   1031478014  correctness_check
#                                                   1280442648  correctness_check
#                                                   1319540244  correctness_check
#                                                   1328559098  correctness_check
#                                                   1332111728  correctness_check
#                                                   1452960576  correctness_check
#                                                   1478370368  correctness_check
#                                                   1946229938  correctness_check
#                                                   2148516230  correctness_check
#                                                   2514692867  correctness_check
#                                                   2817310001  correctness_check
#                                                   2929251895  correctness_check
#                                                   2939990776  correctness_check
#                                                   2969711491  correctness_check
#                                                   3491640172  correctness_check
#                                                   3720363797  correctness_check
#                                                   3902313032  correctness_check
#                                                   3965961082  correctness_check
# {'name': 'data_init', 'type': 'function'}         93128221            data_init
#                                                   461731006           data_init
#                                                   1031478014          data_init
#                                                   1280442648          data_init
#                                                   1319540244          data_init
#                                                   1328559098          data_init
#                                                   1332111728          data_init
#                                                   1452960576          data_init
#                                                   1478370368          data_init
#                                                   1946229938          data_init
#                                                   2148516230          data_init
#                                                   2514692867          data_init
#                                                   2817310001          data_init
#                                                   2929251895          data_init
#                                                   2939990776          data_init
#                                                   2969711491          data_init
#                                                   3491640172          data_init
#                                                   3720363797          data_init
#                                                   3902313032          data_init
#                                                   3965961082          data_init

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 93128221                 2.10.0
# 461731006                2.10.0
# 1031478014               2.10.0
# 1280442648               2.10.0
# 1319540244               2.10.0
# 1328559098               2.10.0
# 1332111728               2.10.0
# 1452960576               2.10.0
# 1478370368               2.10.0
# 1946229938               2.10.0
# 2148516230               2.10.0
# 2514692867               2.10.0
# 2817310001               2.10.0
# 2929251895               2.10.0
# 2939990776               2.10.0
# 2969711491               2.10.0
# 3491640172               2.10.0
# 3720363797               2.10.0
# 3902313032               2.10.0
# 3965961082               2.10.0
#
#                                                  spot.metrics  \
# profile
# 93128221    min#inclusive#sum#time.duration,max#inclusive#...
# 461731006   min#inclusive#sum#time.duration,max#inclusive#...
# 1031478014  min#inclusive#sum#time.duration,max#inclusive#...
# 1280442648  min#inclusive#sum#time.duration,max#inclusive#...
# 1319540244  min#inclusive#sum#time.duration,max#inclusive#...
# 1328559098  min#inclusive#sum#time.duration,max#inclusive#...
# 1332111728  min#inclusive#sum#time.duration,max#inclusive#...
# 1452960576  min#inclusive#sum#time.duration,max#inclusive#...
# 1478370368  min#inclusive#sum#time.duration,max#inclusive#...
# 1946229938  min#inclusive#sum#time.duration,max#inclusive#...
# 2148516230  min#inclusive#sum#time.duration,max#inclusive#...
# 2514692867  min#inclusive#sum#time.duration,max#inclusive#...
# 2817310001  min#inclusive#sum#time.duration,max#inclusive#...
# 2929251895  min#inclusive#sum#time.duration,max#inclusive#...
# 2939990776  min#inclusive#sum#time.duration,max#inclusive#...
# 2969711491  min#inclusive#sum#time.duration,max#inclusive#...
# 3491640172  min#inclusive#sum#time.duration,max#inclusive#...
# 3720363797  min#inclusive#sum#time.duration,max#inclusive#...
# 3902313032  min#inclusive#sum#time.duration,max#inclusive#...
# 3965961082  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 93128221                                              2
# 461731006                                             2
# 1031478014                                            2
# 1280442648                                            2
# 1319540244                                            2
# 1328559098                                            2
# 1332111728                                            2
# 1452960576                                            2
# 1478370368                                            2
# 1946229938                                            2
# 2148516230                                            2
# 2514692867                                            2
# 2817310001                                            2
# 2929251895                                            2
# 2939990776                                            2
# 2969711491                                            2
# 3491640172                                            2
# 3720363797                                            2
# 3902313032                                            2
# 3965961082                                            2
#
#                        spot.options  spot.channels cali.channel  launchdate  \
# profile
# 93128221    cuda.gputime,node.order  regionprofile         spot  1702013366
# 461731006   cuda.gputime,node.order  regionprofile         spot  1701978750
# 1031478014  cuda.gputime,node.order  regionprofile         spot  1701978710
# 1280442648  cuda.gputime,node.order  regionprofile         spot  1702012620
# 1319540244  cuda.gputime,node.order  regionprofile         spot  1702013361
# 1328559098  cuda.gputime,node.order  regionprofile         spot  1702012406
# 1332111728  cuda.gputime,node.order  regionprofile         spot  1702012581
# 1452960576  cuda.gputime,node.order  regionprofile         spot  1702023033
# 1478370368  cuda.gputime,node.order  regionprofile         spot  1702023013
# 1946229938  cuda.gputime,node.order  regionprofile         spot  1702013366
# 2148516230  cuda.gputime,node.order  regionprofile         spot  1701978750
# 2514692867  cuda.gputime,node.order  regionprofile         spot  1701978693
# 2817310001  cuda.gputime,node.order  regionprofile         spot  1702023033
# 2929251895  cuda.gputime,node.order  regionprofile         spot  1702022998
# 2939990776  cuda.gputime,node.order  regionprofile         spot  1702023112
# 2969711491  cuda.gputime,node.order  regionprofile         spot  1702012603
# 3491640172  cuda.gputime,node.order  regionprofile         spot  1702013361
# 3720363797  cuda.gputime,node.order  regionprofile         spot  1702042659
# 3902313032  cuda.gputime,node.order  regionprofile         spot  1702026231
# 3965961082  cuda.gputime,node.order  regionprofile         spot  1701978710
#
#                                                     libraries  \
# profile
# 93128221    [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 461731006   [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1031478014  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1280442648  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1319540244  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1328559098  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1332111728  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1452960576  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1478370368  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1946229938  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2148516230  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2514692867  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2817310001  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2929251895  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2939990776  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2969711491  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 3491640172  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 3720363797  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 3902313032  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 3965961082  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
#
#                               cmdline cluster    Algorithm ProgrammingModel  \
# profile
# 93128221     [./bucket, 512, 4194304]       g  Bucket Sort             CUDA
# 461731006    [./bucket, 512, 4194304]       g  Bucket Sort             CUDA
# 1031478014   [./bucket, 256, 4194304]       g  Bucket Sort             CUDA
# 1280442648  [./bucket, 1024, 4194304]       g  Bucket Sort             CUDA
# 1319540244   [./bucket, 256, 4194304]       g  Bucket Sort             CUDA
# 1328559098    [./bucket, 64, 4194304]       g  Bucket Sort             CUDA
# 1332111728   [./bucket, 256, 4194304]       g  Bucket Sort             CUDA
# 1452960576   [./bucket, 512, 4194304]       g  Bucket Sort             CUDA
# 1478370368   [./bucket, 128, 4194304]       g  Bucket Sort             CUDA
# 1946229938  [./bucket, 1024, 4194304]       g  Bucket Sort             CUDA
# 2148516230  [./bucket, 1024, 4194304]       g  Bucket Sort             CUDA
# 2514692867    [./bucket, 64, 4194304]       g  Bucket Sort             CUDA
# 2817310001   [./bucket, 256, 4194304]       g  Bucket Sort             CUDA
# 2929251895    [./bucket, 64, 4194304]       g  Bucket Sort             CUDA
# 2939990776  [./bucket, 1024, 4194304]       g  Bucket Sort             CUDA
# 2969711491   [./bucket, 512, 4194304]       g  Bucket Sort             CUDA
# 3491640172    [./bucket, 64, 4194304]       g  Bucket Sort             CUDA
# 3720363797   [./bucket, 128, 4194304]       g  Bucket Sort             CUDA
# 3902313032   [./bucket, 128, 4194304]       g  Bucket Sort             CUDA
# 3965961082   [./bucket, 128, 4194304]       g  Bucket Sort             CUDA
#
#            Datatype  SizeOfDatatype  InputSize      InputType  num_threads  \
# profile
# 93128221      float               4    4194304         Sorted          512
# 461731006     float               4    4194304         Random          512
# 1031478014    float               4    4194304         Random          256
# 1280442648    float               4    4194304  ReverseSorted         1024
# 1319540244    float               4    4194304         Sorted          256
# 1328559098    float               4    4194304  ReverseSorted           64
# 1332111728    float               4    4194304  ReverseSorted          256
# 1452960576    float               4    4194304   1%%perturbed          512
# 1478370368    float               4    4194304   1%%perturbed          128
# 1946229938    float               4    4194304         Sorted         1024
# 2148516230    float               4    4194304         Random         1024
# 2514692867    float               4    4194304         Random           64
# 2817310001    float               4    4194304   1%%perturbed          256
# 2929251895    float               4    4194304   1%%perturbed           64
# 2939990776    float               4    4194304   1%%perturbed         1024
# 2969711491    float               4    4194304  ReverseSorted          512
# 3491640172    float               4    4194304         Sorted           64
# 3720363797    float               4    4194304  ReverseSorted          128
# 3902313032    float               4    4194304         Sorted          128
# 3965961082    float               4    4194304         Random          128
#
#             num_blocks  group_num implementation_source
# profile
# 93128221             0         17  Online & Handwritten
# 461731006            0         17  Online & Handwritten
# 1031478014           0         17  Online & Handwritten
# 1280442648           0         17  Online & Handwritten
# 1319540244           0         17  Online & Handwritten
# 1328559098           0         17  Online & Handwritten
# 1332111728           0         17  Online & Handwritten
# 1452960576           0         17  Online & Handwritten
# 1478370368           0         17  Online & Handwritten
# 1946229938           0         17  Online & Handwritten
# 2148516230           0         17  Online & Handwritten
# 2514692867           0         17  Online & Handwritten
# 2817310001           0         17  Online & Handwritten
# 2929251895           0         17  Online & Handwritten
# 2939990776           0         17  Online & Handwritten
# 2969711491           0         17  Online & Handwritten
# 3491640172           0         17  Online & Handwritten
# 3720363797           0         17  Online & Handwritten
# 3902313032           0         17  Online & Handwritten
# 3965961082           0         17  Online & Handwritten

# %%
gb = tk.groupby(["InputSize","InputType"])
# Out:
# 4  thickets created...
# {(4194304, '1%%perturbed'): <thicket.thicket.Thicket object at 0x2b5c7bfdc9a0>, (4194304, 'Random'): <thicket.thicket.Thicket object at 0x2b5c7bf2f1f0>, (4194304, 'ReverseSorted'): <thicket.thicket.Thicket object at 0x2b5c7ecd31c0>, (4194304, 'Sorted'): <thicket.thicket.Thicket object at 0x2b5c7f078070>}

# %%
# gbType = tk.groupby("InputType")
# input_types = gbType.keys()
# dfs = {}
# for key in gbType.keys():
#     thk = gbType[key]
#     gb = thk.groupby("InputSize")
#     ctk = th.Thicket.concat_thickets(
#         thickets=list(gb.values()),
#         headers=list(gb.keys()),
#         axis="columns",
#         metadata_key="num_procs"
#     )

#     ctk.dataframe = ctk.dataframe.reset_index().drop([("node", "")], axis=1)
#     ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
#     dfs[key] = ctk

# dfs['Random'].dataframe

ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_threads"
)

# %%
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", "")], axis=1)
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

# %%
ctk.dataframe
# Out:
#                               (4194304, 1%%perturbed) (4194304, Random)  \
#                                     Avg GPU Time/rank Avg GPU Time/rank
# name              num_threads
# main              64                       341.979468        126.528247
#                   128                      151.465133         31.523202
#                   256                       91.380895          7.330431
#                   512                       63.520380          1.803983
#                   1024                      51.852726          0.576361
# comm              64                         0.003439          0.003412
#                   128                        0.003449          0.003413
#                   256                        0.003396          0.003417
#                   512                        0.003398          0.003411
#                   1024                       0.003426          0.003421
# comm_large        64                         0.003439          0.003412
#                   128                        0.003449          0.003413
#                   256                        0.003396          0.003417
#                   512                        0.003398          0.003411
#                   1024                       0.003426          0.003421
# comp              64                       341.972144        126.521378
#                   128                      151.458182         31.516228
#                   256                       91.373804          7.323131
#                   512                       63.513618          1.797003
#                   1024                      51.845931          0.569523
# comp_large        64                       341.972144        126.521378
#                   128                      151.458182         31.516228
#                   256                       91.373804          7.323131
#                   512                       63.513618          1.797003
#                   1024                      51.845931          0.569523
# comp_small        64                              NaN               NaN
#                   128                             NaN               NaN
#                   256                             NaN               NaN
#                   512                             NaN               NaN
#                   1024                            NaN               NaN
# correctness_check 64                              NaN               NaN
#                   128                             NaN               NaN
#                   256                             NaN               NaN
#                   512                             NaN               NaN
#                   1024                            NaN               NaN
# data_init         64                              NaN               NaN
#                   128                             NaN               NaN
#                   256                             NaN               NaN
#                   512                             NaN               NaN
#                   1024                            NaN               NaN
#
#                               (4194304, ReverseSorted) (4194304, Sorted)
#                                      Avg GPU Time/rank Avg GPU Time/rank
# name              num_threads
# main              64                        126.220451        124.918204
#                   128                        31.222585         31.220316
#                   256                         7.142552          7.037757
#                   512                         1.732489          1.765123
#                   1024                        0.556269          0.550315
# comm              64                          0.004187          0.003425
#                   128                         0.003406          0.004073
#                   256                         0.003422          0.003391
#                   512                         0.003419          0.003429
#                   1024                        0.003414          0.003411
# comm_large        64                          0.004187          0.003425
#                   128                         0.003406          0.004073
#                   256                         0.003422          0.003391
#                   512                         0.003419          0.003429
#                   1024                        0.003414          0.003411
# comp              64                        126.212564        124.911262
#                   128                        31.215352         31.212755
#                   256                         7.135292          7.030888
#                   512                         1.725632          1.758157
#                   1024                        0.549585          0.543637
# comp_large        64                        126.212564        124.911262
#                   128                        31.215352         31.212755
#                   256                         7.135292          7.030888
#                   512                         1.725632          1.758157
#                   1024                        0.549585          0.543637
# comp_small        64                               NaN               NaN
#                   128                              NaN               NaN
#                   256                              NaN               NaN
#                   512                              NaN               NaN
#                   1024                             NaN               NaN
# correctness_check 64                               NaN               NaN
#                   128                              NaN               NaN
#                   256                              NaN               NaN
#                   512                              NaN               NaN
#                   1024                             NaN               NaN
# data_init         64                               NaN               NaN
#                   128                              NaN               NaN
#                   256                              NaN               NaN
#                   512                              NaN               NaN
#                   1024                             NaN               NaN

# %%
function_names = set(ctk.dataframe.index.get_level_values("name"))
threads = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
array_sizes1 = sorted(list(set(ctk.dataframe.columns.get_level_values(0))))

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(df.columns)
    plt.grid(True)
    # plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(threads)
    plt.show()
    return fig, ax

# %%
array_sizes = []
for pair in array_sizes1:
    array_sizes.append(pair[0])
    
array_sizes = list(set(array_sizes))

print(array_sizes)
print(threads)
# Out:
# [4194304]
# [64, 128, 256, 512, 1024]

# %%
for name in function_names:
    for asize in array_sizes:
        tcols = [col for col in ctk.dataframe.columns if col[0][0] == asize]
        plot_mpl(
            df = ctk.dataframe.loc[name][tcols],
            title = f"{name} size: {asize}",
            xlabel = "processes",
            ylabel = "Time (seconds)"
        )

# %%
ctk.dataframe
# Out:
#                               (4194304, 1%%perturbed) (4194304, Random)  \
#                                     Avg GPU Time/rank Avg GPU Time/rank
# name              num_threads
# main              64                       341.979468        126.528247
#                   128                      151.465133         31.523202
#                   256                       91.380895          7.330431
#                   512                       63.520380          1.803983
#                   1024                      51.852726          0.576361
# comm              64                         0.003439          0.003412
#                   128                        0.003449          0.003413
#                   256                        0.003396          0.003417
#                   512                        0.003398          0.003411
#                   1024                       0.003426          0.003421
# comm_large        64                         0.003439          0.003412
#                   128                        0.003449          0.003413
#                   256                        0.003396          0.003417
#                   512                        0.003398          0.003411
#                   1024                       0.003426          0.003421
# comp              64                       341.972144        126.521378
#                   128                      151.458182         31.516228
#                   256                       91.373804          7.323131
#                   512                       63.513618          1.797003
#                   1024                      51.845931          0.569523
# comp_large        64                       341.972144        126.521378
#                   128                      151.458182         31.516228
#                   256                       91.373804          7.323131
#                   512                       63.513618          1.797003
#                   1024                      51.845931          0.569523
# comp_small        64                              NaN               NaN
#                   128                             NaN               NaN
#                   256                             NaN               NaN
#                   512                             NaN               NaN
#                   1024                            NaN               NaN
# correctness_check 64                              NaN               NaN
#                   128                             NaN               NaN
#                   256                             NaN               NaN
#                   512                             NaN               NaN
#                   1024                            NaN               NaN
# data_init         64                              NaN               NaN
#                   128                             NaN               NaN
#                   256                             NaN               NaN
#                   512                             NaN               NaN
#                   1024                            NaN               NaN
#
#                               (4194304, ReverseSorted) (4194304, Sorted)
#                                      Avg GPU Time/rank Avg GPU Time/rank
# name              num_threads
# main              64                        126.220451        124.918204
#                   128                        31.222585         31.220316
#                   256                         7.142552          7.037757
#                   512                         1.732489          1.765123
#                   1024                        0.556269          0.550315
# comm              64                          0.004187          0.003425
#                   128                         0.003406          0.004073
#                   256                         0.003422          0.003391
#                   512                         0.003419          0.003429
#                   1024                        0.003414          0.003411
# comm_large        64                          0.004187          0.003425
#                   128                         0.003406          0.004073
#                   256                         0.003422          0.003391
#                   512                         0.003419          0.003429
#                   1024                        0.003414          0.003411
# comp              64                        126.212564        124.911262
#                   128                        31.215352         31.212755
#                   256                         7.135292          7.030888
#                   512                         1.725632          1.758157
#                   1024                        0.549585          0.543637
# comp_large        64                        126.212564        124.911262
#                   128                        31.215352         31.212755
#                   256                         7.135292          7.030888
#                   512                         1.725632          1.758157
#                   1024                        0.549585          0.543637
# comp_small        64                               NaN               NaN
#                   128                              NaN               NaN
#                   256                              NaN               NaN
#                   512                              NaN               NaN
#                   1024                             NaN               NaN
# correctness_check 64                               NaN               NaN
#                   128                              NaN               NaN
#                   256                              NaN               NaN
#                   512                              NaN               NaN
#                   1024                             NaN               NaN
# data_init         64                               NaN               NaN
#                   128                              NaN               NaN
#                   256                              NaN               NaN
#                   512                              NaN               NaN
#                   1024                             NaN               NaN

# %%
# ctk.dataframe.loc[[("main", 2), ("main", 8)]]
tdf = ctk.dataframe.loc[[("comp_large", i) for i in [64, 256, 1024]], [col for col in ctk.dataframe.columns if col[0][1] == "Random"]]

# %%
tdf
# Out:
#                        (4194304, Random)
#                        Avg GPU Time/rank
# name       num_threads
# comp_large 64                 126.521378
#            256                  7.323131
#            1024                 0.569523

# %%
# tdf.drop(columns=[((67108864, 'Random'), 'Avg time/rank'), ((268435456, 'Random'), 'Avg time/rank')])
# tdf.columns

# %%
# weak = [0.515468, 0.514026, 0.569523] # Avg GPU Time/Rank for (64, 2^18), (256, 2^20), and (1024, 2^22)
weak = [2.887824, 12.532250, 90.684550] # Avg GPU Time/Rank for (64, 2^18), (256, 2^20), and (1024, 2^22)
procs = [64, 256, 1024]

# %%
def plot_weak(x, y, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        x,
        y,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend("comp_large")
#     ax.set_ylim([0.35, 0.75])
    ax.set_xlim([32, 2048])
    plt.grid(True)
    # plt.yscale("log", base=10)
    plt.xscale("log", base=2)
    plt.xticks(threads)
    plt.show()
    return fig, ax

# %%
plot_weak(procs, 
          weak,
          title = "Weak Scaling with Random Input for Comp_large",
          xlabel = "Threads",
          ylabel = "Time (seconds)"
         )
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <Axes: title={'center': 'Weak Scaling with Random Input for Comp_large'}, xlabel='Threads', ylabel='Time (seconds)'>)

# %%
# Gets Speedups
temp_df = ctk.dataframe.loc["main"]
temp_df = temp_df.iloc[0] / temp_df
temp_df
# Out:
#             (4194304, 1%%perturbed) (4194304, Random)  \
#                       Avg time/rank     Avg time/rank
# num_threads
# 64                         1.000000          1.000000
# 128                        2.253264          3.957444
# 256                        3.725791         16.002552
# 512                        5.345812         52.490887
# 1024                       6.537176        104.783330
#
#             (4194304, ReverseSorted) (4194304, Sorted)
#                        Avg time/rank     Avg time/rank
# num_threads
# 64                          1.000000          1.000000
# 128                         3.990087          3.940888
# 256                        16.512078         16.789681
# 512                        55.724234         54.269741
# 1024                      114.493852        114.047003

# %%
temp_df.loc[64][temp_df.columns[0]]
# Out:
# 1.0

# %%
for asize in array_sizes:
    tcols = [col for col in temp_df.columns if col[0][0] == asize]
#     print(tcols)
    plot_mpl(
        df = temp_df.loc[threads][tcols],
        title = f"Speed Up w/ Random Input for Size: {asize}",
        xlabel = "processes",
        ylabel = "Time (seconds)"
    )
